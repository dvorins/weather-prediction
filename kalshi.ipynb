# %%
import uuid
import kalshi_python
from kalshi_python.models import *
from pprint import pprint

config = kalshi_python.Configuration()
# Comment the line below to use production
config.host = 'https://demo-api.kalshi.co/trade-api/v2'

# Create an API configuration passing your credentials.
# Use this if you want the kalshi_python sdk to manage the authentication for you.
kalshi_api = kalshi_python.ApiInstance(
    email='samjd101@gmail.com',
    password='SVwkQqrF2R6dDAb',
    configuration=config,
)

def convert_to_kalshi_date(date):
    # Split the date into year, month, and day components
    year, month, day = date.split('-')

    # Convert the month from numeric to abbreviated format
    month_abbr = {
        '01': 'JAN',
        '02': 'FEB',
        '03': 'MAR',
        '04': 'APR',
        '05': 'MAY',
        '06': 'JUN',
        '07': 'JUL',
        '08': 'AUG',
        '09': 'SEP',
        '10': 'OCT',
        '11': 'NOV',
        '12': 'DEC'
    }

    # Convert year to last two digits
    year = year[-2:]

    # Return the converted date in Kalshi compatible format
    return year + month_abbr[month] + day

# Alternatively you can manage the authentication yourself by doing:
# kalshi_api = kalshi_python.ApiInstance(
#     configuration=config,
# )
# loginResponse = kalshi_api.login(LoginRequest(email='YOUR_EMAIL_HERE', password='YOUR_PASSWORD_HERE'))
# token = loginResponse.token
# kalshi_api.set_api_token(loginResponse.token)
# # The token used above can eventually expire if you stop using it for more than 30 minutes.
# # In that case you should redo the process by doing a new login request and setting the api token again in the same way.

# Checks if the exchange is available.
exchangeStatus = kalshi_api.get_exchange_status()
print('Exchange status response: ')
pprint(exchangeStatus)

# Gets the data for a specific series.
seriesTicker = 'FED'
seriesResponse = kalshi_api.get_series(seriesTicker)
print('\nSeries: ' + seriesTicker)
pprint(seriesResponse)

# Gets the events for a specific series.
seriesTicker = 'FED'
eventsResponse = kalshi_api.get_events(series_ticker=seriesTicker)
print('\nEvents for series: ' + seriesTicker)
pprint(eventsResponse)

# Gets the data for a specific event.
eventTicker = 'FED-23DEC'
eventResponse = kalshi_api.get_event(eventTicker)
print('\nEvent: ' + seriesTicker)
pprint(eventResponse)

# Gets the data for a specific market.
marketTicker = 'FED-23DEC-T3.00'
marketResponse = kalshi_api.get_market(marketTicker)
print('\nMarket: ' + marketTicker)
pprint(marketResponse)

# Gets the orderbook for a specific market.
marketTicker = 'FED-23DEC-T3.00'
orderbookResponse = kalshi_api.get_market_orderbook(marketTicker)
print('\nOrderbook for market: ' + marketTicker)
pprint(orderbookResponse)

# Gets the market price history for a specific market.
marketTicker = 'FED-23DEC-T3.00'
historyResponse = kalshi_api.get_market_history(marketTicker)
print('\nMarket price history for market: ' + marketTicker)
pprint(historyResponse)

# Gets the balance for your kalshi account.
balanceResponse = kalshi_api.get_balance()
print('\nUser balance: ')
pprint(balanceResponse)
# Out:
# Exchange status response:
# {'exchange_active': True, 'trading_active': True}
#
# Series: FED
# {'series': {'frequency': 'custom', 'ticker': 'FED', 'title': 'Fed funds rate'}}
#
# Events for series: FED
# {'cursor': '',
#  'events': [{'category': 'Economics',
#              'event_ticker': 'FED-25JAN',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-01-29T19:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Jan 2025',
#              'title': 'Fed funds rate in Jan 2025?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24DEC',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-12-18T19:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Dec 2024',
#              'title': 'Fed funds rate in Dec 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24NOV',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-11-07T19:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Nov 2024',
#              'title': 'Fed funds rate in Nov 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24SEP',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-09-18T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Sep 2024',
#              'title': 'Fed funds rate in Sep 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24JUL',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-07-31T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Jul 2024',
#              'title': 'Fed funds rate in Jul 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24JUN',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-06-12T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Jun 2024',
#              'title': 'Fed funds rate in Jun 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24MAY',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-05-01T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In May 2024',
#              'title': 'Fed funds rate in May 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24MAR',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-03-20T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Mar 2024',
#              'title': 'Fed funds rate in Mar 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-24JAN',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2024-01-31T19:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Jan 2024',
#              'title': 'Fed funds rate in Jan 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23DEC',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-12-13T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Dec 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23NOV',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-11-01T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Nov 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23SEP',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-09-20T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Sep 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23JUL',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-07-26T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Jul 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23JUN',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-06-14T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Jun 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23MAY',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-05-03T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In May 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23MAR',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-03-22T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Mar 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-23FEB',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2023-02-01T12:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Feb 2023',
#              'title': 'How much will the Federal Reserve increase interest '
#                       'rates?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-22DEC',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'December 2022 meeting',
#              'title': 'What will the **federal funds rate** be at the end of '
#                       '2022?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-22NOV',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'November 2022 meeting',
#              'title': 'How will the **Fed set interest rates** in November?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-22SEP',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'September 2022 meeting',
#              'title': 'How will the **Fed set interest rates** in September?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-22JUL',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'July 2022 meeting',
#              'title': 'How will the **Fed set interest rates** in July?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-22JUN',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In Jun 2022 meeting',
#              'title': 'How will the **Fed set interest rates** in June?'}]}
#
# Event: FED
# {'event': {'category': 'Economics',
#            'event_ticker': 'FED-23DEC',
#            'mutually_exclusive': False,
#            'series_ticker': 'FED',
#            'strike_date': '2023-12-13T12:00:00Z',
#            'strike_period': None,
#            'sub_title': 'In Dec 2023',
#            'title': 'How much will the Federal Reserve increase interest '
#                     'rates?'},
#  'markets': [{'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 3,
#               'last_price': 98,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 949,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 98,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 98,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>3.00%',
#               'ticker': 'FED-23DEC-T3.00',
#               'title': '',
#               'volume': 1313,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 98},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 3.25,
#               'last_price': 97,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 896,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 97,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 97,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>3.25%',
#               'ticker': 'FED-23DEC-T3.25',
#               'title': '',
#               'volume': 896,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 97},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 3.5,
#               'last_price': 98,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 929,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 98,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 98,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>3.50%',
#               'ticker': 'FED-23DEC-T3.50',
#               'title': '',
#               'volume': 929,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 98},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 3.75,
#               'last_price': 99,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 1109,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 99,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 99,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>3.75%',
#               'ticker': 'FED-23DEC-T3.75',
#               'title': '',
#               'volume': 1109,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 99},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 4,
#               'last_price': 98,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 902,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 98,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 98,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>4.00%',
#               'ticker': 'FED-23DEC-T4.00',
#               'title': '',
#               'volume': 902,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 98},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 4.25,
#               'last_price': 98,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 749,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 98,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 98,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>4.25%',
#               'ticker': 'FED-23DEC-T4.25',
#               'title': '',
#               'volume': 749,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 98},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 4.5,
#               'last_price': 97,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 897,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 97,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 97,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>4.50%',
#               'ticker': 'FED-23DEC-T4.50',
#               'title': '',
#               'volume': 897,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 97},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 4.75,
#               'last_price': 99,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 937,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 99,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 99,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>4.75%',
#               'ticker': 'FED-23DEC-T4.75',
#               'title': '',
#               'volume': 937,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 99},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 5,
#               'last_price': 98,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 960,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 98,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 98,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>5.00%',
#               'ticker': 'FED-23DEC-T5.00',
#               'title': '',
#               'volume': 960,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 98},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 5.25,
#               'last_price': 96,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 800,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 96,
#               'previous_yes_ask': 100,
#               'previous_yes_bid': 96,
#               'result': 'yes',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>5.25%',
#               'ticker': 'FED-23DEC-T5.25',
#               'title': '',
#               'volume': 1076,
#               'volume_24h': 0,
#               'yes_ask': 100,
#               'yes_bid': 96},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 5.5,
#               'last_price': 50,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 0,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 50,
#               'previous_yes_ask': 45,
#               'previous_yes_bid': 42,
#               'result': 'no',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>5.50%',
#               'ticker': 'FED-23DEC-T5.50',
#               'title': '',
#               'volume': 2084,
#               'volume_24h': 0,
#               'yes_ask': 45,
#               'yes_bid': 42},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 5.75,
#               'last_price': 2,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 568,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 2,
#               'previous_yes_ask': 3,
#               'previous_yes_bid': 2,
#               'result': 'no',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>5.75%',
#               'ticker': 'FED-23DEC-T5.75',
#               'title': '',
#               'volume': 1366,
#               'volume_24h': 0,
#               'yes_ask': 3,
#               'yes_bid': 2},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 6,
#               'last_price': 4,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 1201,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 4,
#               'previous_yes_ask': 3,
#               'previous_yes_bid': 0,
#               'result': 'no',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>6.00%',
#               'ticker': 'FED-23DEC-T6.00',
#               'title': '',
#               'volume': 1201,
#               'volume_24h': 0,
#               'yes_ask': 3,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 6.25,
#               'last_price': 3,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 1637,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 3,
#               'previous_yes_ask': 3,
#               'previous_yes_bid': 0,
#               'result': 'no',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>6.25%',
#               'ticker': 'FED-23DEC-T6.25',
#               'title': '',
#               'volume': 1642,
#               'volume_24h': 0,
#               'yes_ask': 3,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': '',
#               'close_time': '2023-12-13T18:55:00Z',
#               'custom_strike': None,
#               'event_ticker': '',
#               'expiration_time': '2023-12-20T19:05:00Z',
#               'expiration_value': '5.50%',
#               'floor_strike': 6.5,
#               'last_price': 2,
#               'liquidity': 0,
#               'no_ask': 0,
#               'no_bid': 0,
#               'open_interest': 1052,
#               'open_time': '2022-11-04T19:26:15.886415Z',
#               'previous_price': 2,
#               'previous_yes_ask': 2,
#               'previous_yes_bid': 0,
#               'result': 'no',
#               'risk_limit_cents': 10000000,
#               'status': 'finalized',
#               'strike_type': 'greater',
#               'subtitle': '>6.50%',
#               'ticker': 'FED-23DEC-T6.50',
#               'title': '',
#               'volume': 1052,
#               'volume_24h': 0,
#               'yes_ask': 2,
#               'yes_bid': 0}]}
#
# Market: FED-23DEC-T3.00
# {'market': {'can_close_early': True,
#             'cap_strike': None,
#             'category': 'Economics',
#             'close_time': '2023-12-13T18:55:00Z',
#             'custom_strike': None,
#             'event_ticker': 'FED-23DEC',
#             'expiration_time': '2023-12-20T19:05:00Z',
#             'expiration_value': '5.50%',
#             'floor_strike': 3,
#             'last_price': 98,
#             'liquidity': 0,
#             'no_ask': 2,
#             'no_bid': 0,
#             'open_interest': 949,
#             'open_time': '2022-11-04T19:26:15.886415Z',
#             'previous_price': 98,
#             'previous_yes_ask': 100,
#             'previous_yes_bid': 98,
#             'result': 'yes',
#             'risk_limit_cents': 10000000,
#             'status': 'finalized',
#             'strike_type': 'greater',
#             'subtitle': '>3.00%',
#             'ticker': 'FED-23DEC-T3.00',
#             'title': 'Will the upper bound of the federal funds rate be above '
#                      "3.00% following the Fed's December meeting?",
#             'volume': 1313,
#             'volume_24h': 0,
#             'yes_ask': 100,
#             'yes_bid': 98}}
#
# Orderbook for market: FED-23DEC-T3.00
# {'orderbook': {'no': [], 'yes': []}}
#
# Market price history for market: FED-23DEC-T3.00
# {'cursor': 'CgwI8JebmwYQuKXt3wI',
#  'history': [{'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667596166,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667596166,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667596169,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667596169,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667596169,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667596169,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600570,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600570,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600570,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600570,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600572,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600572,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600572,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667600572,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604921,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604921,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604921,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604921,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604923,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604923,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604923,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667604923,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609765,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609765,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609765,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609765,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609768,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609768,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609768,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667609768,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614588,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614588,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614588,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614588,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614591,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614591,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614591,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667614591,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619486,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619486,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619486,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619486,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619489,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619489,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619489,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667619489,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667623730,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667623730,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667652209,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667652209,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667652212,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667652212,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667652212,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667652212,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656931,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656931,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656931,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656931,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656934,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656934,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656934,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667656934,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661722,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661722,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661722,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661723,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661725,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661725,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661725,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667661725,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666543,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666544,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666544,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666544,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666546,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666546,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666546,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667666546,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671421,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671421,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671421,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671421,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671424,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671424,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671424,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667671424,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676372,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676372,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676372,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676372,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676374,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676374,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676375,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667676375,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667681262,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667681262,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667681262,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 65,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667681262,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 35,
#               'yes_price': 0},
#              {'no_ask': 77,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667681264,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 23,
#               'yes_price': 0},
#              {'no_ask': 100,
#               'no_bid': 0,
#               'open_interest': 0,
#               'ts': 1667681264,
#               'volume': 0,
#               'yes_ask': 100,
#               'yes_bid': 0,
#               'yes_price': 0}],
#  'ticker': 'FED-23DEC-T3.00'}
#
# User balance:
# {'balance': 1001916}

# %%
# NAMES FOR THE SERIES
nycTicker = 'HIGHNY'
ausTicker = 'HIGHAUS'
chiTicker = 'HIGHCHI'
miaTicker = 'HIGHMIA'


# Gets the market price history for a specific market.
marketTicker = 'HIGHNY-24MAR18-B53.5'
historyResponse = kalshi_api.get_market_history(marketTicker)
print('\nMarket price history for market: ' + marketTicker)
pprint(historyResponse)

'''   


format for estimates:

'subtitle': '53° to 54°',
'ticker': 'HIGHNY-24MAR18-B53.5',

'subtitle': '46° or below',
'ticker': 'HIGHNY-24MAR18-T47',

'subtitle': '55° or above',
'ticker': 'HIGHNY-24MAR18-T54',

'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/mf/txv8p7fx2yz68v4bx9pfbxf80000gn/T/ipykernel_15843/2357158575.py in <module>
#       8 # Gets the market price history for a specific market.
#       9 marketTicker = 'HIGHNY-24MAR18-B53.5'
# ---> 10 historyResponse = kalshi_api.get_market_history(marketTicker)
#      11 print('\nMarket price history for market: ' + marketTicker)
#      12 pprint(historyResponse)
#
# NameError: name 'kalshi_api' is not defined

# %%
if exchangeStatus.trading_active:
    # Submit an order for 10 yes contracts at 50cents on 'FED-23DEC-T3.00'.
    orderUuid = str(uuid.uuid4())
    orderResponse = kalshi_api.create_order(CreateOrderRequest(
        ticker='HIGHAUS-24MAR18-B67.5',
        action='buy',
        type='limit',
        yes_price=1,
        count=1,
        client_order_id=orderUuid,
        side='no',
    ))
    print('\nOrder submitted: ')
    pprint(orderResponse)
else:
    print('\nThe exchange is not trading active, no orders will be sent right now.')
# Out:
# Order submitted:
# {'order': {'action': 'buy',
#            'client_order_id': '054d2430-ce2d-414c-b6fb-c74d8972a903',
#            'created_time': '2024-03-19T01:18:03.064539Z',
#            'expiration_time': None,
#            'no_price': 99,
#            'order_id': '095c5853-a2bf-4edb-8a97-889be999a9aa',
#            'side': 'no',
#            'status': 'executed',
#            'ticker': 'HIGHAUS-24MAR18-B67.5',
#            'type': 'limit',
#            'user_id': '85e87b65-dfb8-4ba7-a122-d7e187de00aa',
#            'yes_price': 1}}

# %%
if exchangeStatus.trading_active:
    # Submit an order for 10 yes contracts at 50cents on 'FED-23DEC-T3.00'.
    orderUuid = str(uuid.uuid4())
    orderResponse = kalshi_api.create_order(CreateOrderRequest(
        ticker='HIGHCHI-24MAR19-B51.5',
        action='buy',
        type='limit',
        yes_price=1,
        count=1,
        client_order_id=orderUuid,
        side='yes',
    ))
    print('\nOrder submitted: ')
    pprint(orderResponse)
else:
    print('\nThe exchange is not trading active, no orders will be sent right now.')
# Out:
# Order submitted:
# {'order': {'action': 'buy',
#            'client_order_id': '1385aa00-d032-4d95-89e9-63f89fc01250',
#            'created_time': '2024-03-19T18:21:01.090107Z',
#            'expiration_time': None,
#            'no_price': 99,
#            'order_id': '8aeee6dd-07a4-4a45-95f8-7e4e02c31da5',
#            'side': 'yes',
#            'status': 'resting',
#            'ticker': 'HIGHCHI-24MAR19-B51.5',
#            'type': 'limit',
#            'user_id': '85e87b65-dfb8-4ba7-a122-d7e187de00aa',
#            'yes_price': 1}}

# %%
# Gets the events for a specific series.
seriesTicker = 'HIGHCHI'
eventsResponse = kalshi_api.get_events(series_ticker=seriesTicker)
print('\nEvents for series: ' + seriesTicker)
pprint(eventsResponse)
# Out:
# Events for series: HIGHCHI
# {'cursor': '',
#  'events': [{'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR20',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-21T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 20, 2024',
#              'title': 'Highest temperature in Chicago on Mar 20, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR19',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-20T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 19, 2024',
#              'title': 'Highest temperature in Chicago on Mar 19, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR18',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-19T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 18, 2024',
#              'title': 'Highest temperature in Chicago on Mar 18, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR17',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-18T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 17, 2024',
#              'title': 'Highest temperature in Chicago on Mar 17, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR16',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-17T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 16, 2024',
#              'title': 'Highest temperature in Chicago on Mar 16, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR15',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-16T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 15, 2024',
#              'title': 'Highest temperature in Chicago on Mar 15, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR14',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-15T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 14, 2024',
#              'title': 'Highest temperature in Chicago on Mar 14, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR13',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-14T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 13, 2024',
#              'title': 'Highest temperature in Chicago on Mar 13, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR12',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-13T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 12, 2024',
#              'title': 'Highest temperature in Chicago on Mar 12, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR11',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-12T03:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 11, 2024',
#              'title': 'Highest temperature in Chicago on Mar 11, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR10',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-11T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 10, 2024',
#              'title': 'Highest temperature in Chicago on Mar 10, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR09',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-10T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 9, 2024',
#              'title': 'Highest temperature in Chicago on Mar 9, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR08',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-09T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 8, 2024',
#              'title': 'Highest temperature in Chicago on Mar 8, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR07',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-08T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 7, 2024',
#              'title': 'Highest temperature in Chicago on Mar 7, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR06',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-07T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 6, 2024',
#              'title': 'Highest temperature in Chicago on Mar 6, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR05',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-06T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 5, 2024',
#              'title': 'Highest temperature in Chicago on Mar 5, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR04',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-05T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 4, 2024',
#              'title': 'Highest temperature in Chicago on Mar 4, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR03',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-04T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 3, 2024',
#              'title': 'Highest temperature in Chicago on Mar 3, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR02',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-03T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 2, 2024',
#              'title': 'Highest temperature in Chicago on Mar 2, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24MAR01',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-02T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 1, 2024',
#              'title': 'Highest temperature in Chicago on Mar 1, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB29',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-03-01T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 29, 2024',
#              'title': 'Highest temperature in Chicago on Feb 29, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-2-24FEB28',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-29T11:14:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 28, 2024 (alternate strikes)',
#              'title': 'Highest temperature in Chicago on Feb 28, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB28',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-29T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 28, 2024',
#              'title': 'Highest temperature in Chicago on Feb 28, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB27',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-28T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 27, 2024',
#              'title': 'Highest temperature in Chicago on Feb 27, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB26',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-27T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 26, 2024',
#              'title': 'Highest temperature in Chicago on Feb 26, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB25',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-26T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 25, 2024',
#              'title': 'Highest temperature in Chicago on Feb 25, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB24',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-25T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 24, 2024',
#              'title': 'Highest temperature in Chicago on Feb 24, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB23',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-24T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 23, 2024',
#              'title': 'Highest temperature in Chicago on Feb 23, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB22',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-23T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 22, 2024',
#              'title': 'Highest temperature in Chicago on Feb 22, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB21',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-22T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 21, 2024',
#              'title': 'Highest temperature in Chicago on Feb 21, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB20',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-21T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 20, 2024',
#              'title': 'Highest temperature in Chicago on Feb 20, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB19',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-20T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 19, 2024',
#              'title': 'Highest temperature in Chicago on Feb 19, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB18',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-19T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 18, 2024',
#              'title': 'Highest temperature in Chicago on Feb 18, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB17',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-18T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 17, 2024',
#              'title': 'Highest temperature in Chicago on Feb 17, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB16',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-17T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 16, 2024',
#              'title': 'Highest temperature in Chicago on Feb 16, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB15',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-16T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 15, 2024',
#              'title': 'Highest temperature in Chicago on Feb 15, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB14',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-15T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 14, 2024',
#              'title': 'Highest temperature in Chicago on Feb 14, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB13',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-14T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 13, 2024',
#              'title': 'Highest temperature in Chicago on Feb 13, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB12',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-13T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 12, 2024',
#              'title': 'Highest temperature in Chicago on Feb 12, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB11',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-12T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 11, 2024',
#              'title': 'Highest temperature in Chicago on Feb 11, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB10',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-11T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 10, 2024',
#              'title': 'Highest temperature in Chicago on Feb 10, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB09',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-10T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 9, 2024',
#              'title': 'Highest temperature in Chicago on Feb 9, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB08',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-09T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 8, 2024',
#              'title': 'Highest temperature in Chicago on Feb 8, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB07',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-08T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 7, 2024',
#              'title': 'Highest temperature in Chicago on Feb 7, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB06',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-07T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 6, 2024',
#              'title': 'Highest temperature in Chicago on Feb 6, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB05',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-06T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 5, 2024',
#              'title': 'Highest temperature in Chicago on Feb 5, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB04',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-05T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 4, 2024',
#              'title': 'Highest temperature in Chicago on Feb 4, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB03',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-04T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 3, 2024',
#              'title': 'Highest temperature in Chicago on Feb 3, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB02',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-03T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 2, 2024',
#              'title': 'Highest temperature in Chicago on Feb 2, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24FEB01',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-02T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Feb 1, 2024',
#              'title': 'Highest temperature in Chicago on Feb 1, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN31',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-02-01T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 31, 2024',
#              'title': 'Highest temperature in Chicago on Jan 31, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN30',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-31T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 30, 2024',
#              'title': 'Highest temperature in Chicago on Jan 30, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN29',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-30T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 29, 2024',
#              'title': 'Highest temperature in Chicago on Jan 29, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN28',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-29T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 28, 2024',
#              'title': 'Highest temperature in Chicago on Jan 28, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN27',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-28T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 27, 2024',
#              'title': 'Highest temperature in Chicago on Jan 27, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN26',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-27T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 26, 2024',
#              'title': 'Highest temperature in Chicago on Jan 26, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN25',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-26T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 25, 2024',
#              'title': 'Highest temperature in Chicago on Jan 25, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN24',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-25T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 24, 2024',
#              'title': 'Highest temperature in Chicago on Jan 24, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN23',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-24T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 23, 2024',
#              'title': 'Highest temperature in Chicago on Jan 23, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN22',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-23T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 22, 2024',
#              'title': 'Highest temperature in Chicago on Jan 22, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN21',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-22T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 21, 2024',
#              'title': 'Highest temperature in Chicago on Jan 21, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN20',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-21T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 20, 2024',
#              'title': 'Highest temperature in Chicago on Jan 20, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN19',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-20T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 19, 2024',
#              'title': 'Highest temperature in Chicago on Jan 19, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN18',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-19T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 18, 2024',
#              'title': 'What will the high be in Chicago on Jan 18, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN17',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-18T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 17, 2024',
#              'title': 'What will the high be in Chicago on Jan 17, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN16',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-17T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 16, 2024',
#              'title': 'What will the high be in Chicago on Jan 16, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN15',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-16T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 15, 2024',
#              'title': 'What will the high be in Chicago on Jan 15, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN14',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-15T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 14, 2024',
#              'title': 'What will the high be in Chicago on Jan 14, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN13',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-14T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 13, 2024',
#              'title': 'What will the high be in Chicago on Jan 13, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN12',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-13T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 12, 2024',
#              'title': 'What will the high be in Chicago on Jan 12, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN11',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-12T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 11, 2024',
#              'title': 'What will the high be in Chicago on Jan 11, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN10',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-11T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 10, 2024',
#              'title': 'What will the high be in Chicago on Jan 10, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN09',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-10T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 9, 2024',
#              'title': 'What will the high be in Chicago on Jan 9, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN08',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-09T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 8, 2024',
#              'title': 'What will the high be in Chicago on Jan 8, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN07',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-08T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 7, 2024',
#              'title': 'What will the high be in Chicago on Jan 7, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN06',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-07T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 6, 2024',
#              'title': 'What will the high be in Chicago on Jan 6, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN05',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-06T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 5, 2024',
#              'title': 'What will the high be in Chicago on Jan 5, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN04',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-05T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 4, 2024',
#              'title': 'What will the high be in Chicago on Jan 4, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN03',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-04T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 3, 2024',
#              'title': 'What will the high be in Chicago on Jan 3, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN02',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-03T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 2, 2024',
#              'title': 'What will the high be in Chicago on Jan 2, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-24JAN01',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-02T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jan 1, 2024',
#              'title': 'What will the high be in Chicago on Jan 1, 2024?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC31',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2024-01-01T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 31, 2023',
#              'title': 'What will the high be in Chicago on Dec 31, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC30',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-31T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 30, 2023',
#              'title': 'What will the high be in Chicago on Dec 30, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC29',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-30T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 29, 2023',
#              'title': 'What will the high be in Chicago on Dec 29, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC28',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-29T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 28, 2023',
#              'title': 'What will the high be in Chicago on Dec 28, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC27',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-28T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 27, 2023',
#              'title': 'What will the high be in Chicago on Dec 27, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC26',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-27T06:14:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 26, 2023',
#              'title': 'What will the high be in Chicago on Dec 26, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC25',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-26T07:29:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 25, 2023',
#              'title': 'What will the high be in Chicago on Dec 25, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC23',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-24T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 23, 2023',
#              'title': 'What will the high be in Chicago on Dec 23, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC22',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-23T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 22, 2023',
#              'title': 'What will the high be in Chicago on Dec 22, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC21',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-22T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 21, 2023',
#              'title': 'What will the high be in Chicago on Dec 21, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC20',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-21T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 20, 2023',
#              'title': 'What will the high be in Chicago on Dec 20, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC19',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-20T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 19, 2023',
#              'title': 'What will the high be in Chicago on Dec 19, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC18',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-19T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 18, 2023',
#              'title': 'What will the high be in Chicago on Dec 18, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC17',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-18T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 17, 2023',
#              'title': 'What will the high be in Chicago on Dec 17, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC16',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-17T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 16, 2023',
#              'title': 'What will the high be in Chicago on Dec 16, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC15',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-16T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 15, 2023',
#              'title': 'What will the high be in Chicago on Dec 15, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC14',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-15T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 14, 2023',
#              'title': 'What will the high be in Chicago on Dec 14, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC13',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-14T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 13, 2023',
#              'title': 'What will the high be in Chicago on Dec 13, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC12',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-13T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 12, 2023',
#              'title': 'What will the high be in Chicago on Dec 12, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC11',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-12T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 11, 2023',
#              'title': 'What will the high be in Chicago on Dec 11, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC10',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-11T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 10, 2023',
#              'title': 'What will the high be in Chicago on Dec 10, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC09',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-10T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 9, 2023',
#              'title': 'What will the high be in Chicago on Dec 9, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC08',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-09T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 8, 2023',
#              'title': 'What will the high be in Chicago on Dec 8, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC07',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-08T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 7, 2023',
#              'title': 'What will the high be in Chicago on Dec 7, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC06',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-07T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 6, 2023',
#              'title': 'What will the high be in Chicago on Dec 6, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC05',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-06T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 5, 2023',
#              'title': 'What will the high be in Chicago on Dec 5, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC04',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-05T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 4, 2023',
#              'title': 'What will the high be in Chicago on Dec 4, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC03',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-04T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 3, 2023',
#              'title': 'What will the high be in Chicago on Dec 3, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC02',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-03T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 2, 2023',
#              'title': 'What will the high be in Chicago on Dec 2, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23DEC01',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-02T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 1, 2023',
#              'title': 'What will the high be in Chicago on Dec 1, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV30',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-12-01T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 30, 2023',
#              'title': 'What will the high be in Chicago on Nov 30, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV29',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-30T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 29, 2023',
#              'title': 'What will the high be in Chicago on Nov 29, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV28',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-29T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 28, 2023',
#              'title': 'What will the high be in Chicago on Nov 28, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV27',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-28T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 27, 2023',
#              'title': 'What will the high be in Chicago on Nov 27, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV26',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-27T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 26, 2023',
#              'title': 'What will the high be in Chicago on Nov 26, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV25',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-26T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 25, 2023',
#              'title': 'What will the high be in Chicago on Nov 25, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV24',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-25T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 24, 2023',
#              'title': 'What will the high be in Chicago on Nov 24, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV23',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-24T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 23, 2023',
#              'title': 'What will the high be in Chicago on Nov 23, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV22',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-23T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 22, 2023',
#              'title': 'What will the high be in Chicago on Nov 22, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV21',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-22T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 21, 2023',
#              'title': 'What will the high be in Chicago on Nov 21, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV20',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-21T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 20, 2023',
#              'title': 'What will the high be in Chicago on Nov 20, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV19',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-20T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 19, 2023',
#              'title': 'What will the high be in Chicago on Nov 19, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV18',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': '2023-11-19T04:59:00Z',
#              'strike_period': None,
#              'sub_title': 'On Nov 18, 2023',
#              'title': 'What will the high be in Chicago on Nov 18, 2023?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-23NOV17',
#              'mutually_exclusive': True,
# ...
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Nov 7, 2022',
#              'title': 'What will the high be in Chicago on Nov 7, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22NOV06',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Nov 6, 2022',
#              'title': 'What will the high be in Chicago on Nov 6, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22NOV05',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Nov 5, 2022',
#              'title': 'What will the high be in Chicago on Nov 5, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22NOV04',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Nov 4, 2022',
#              'title': 'What will the high be in Chicago on Nov 4, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22NOV01',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Nov 1, 2022',
#              'title': 'What will the high be in Chicago on Nov 1, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT31',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 31, 2022',
#              'title': 'What will the high be in Chicago on Oct 31, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT30',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 30, 2022',
#              'title': 'What will the high be in Chicago on Oct 30, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT29',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 29, 2022',
#              'title': 'What will the high be in Chicago on Oct 29, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT28',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 28, 2022',
#              'title': 'What will the high be in Chicago on Oct 28, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT27',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 27, 2022',
#              'title': 'What will the high be in Chicago on Oct 27, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT26',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 26, 2022',
#              'title': 'What will the high be in Chicago on Oct 26, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT25',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 25, 2022',
#              'title': 'What will the high be in Chicago on Oct 25, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT24',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 24, 2022',
#              'title': 'What will the high be in Chicago on Oct 24, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT23',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 23, 2022',
#              'title': 'What will the high be in Chicago on Oct 23, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT22',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 22, 2022',
#              'title': 'What will the high be in Chicago on Oct 22, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT21',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 21, 2022',
#              'title': 'What will the high be in Chicago on Oct 21, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT20',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 20, 2022',
#              'title': 'What will the high be in Chicago on Oct 20, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT19',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 19, 2022',
#              'title': 'What will the high be in Chicago on Oct 19, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT18',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 18, 2022',
#              'title': 'What will the high be in Chicago on Oct 18, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT17',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 17, 2022',
#              'title': 'What will the high be in Chicago on Oct 17, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT16',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 16, 2022',
#              'title': 'What will the high be in Chicago on Oct 16, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT15',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 15, 2022',
#              'title': 'What will the high be in Chicago on Oct 15, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT14',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 14, 2022',
#              'title': 'What will the high be in Chicago on Oct 14, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT13',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 13, 2022',
#              'title': 'What will the high be in Chicago on Oct 13, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT12',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 12, 2022',
#              'title': 'What will the high be in Chicago on Oct 12, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT11',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 11, 2022',
#              'title': 'What will the high be in Chicago on Oct 11, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT10',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 10, 2022',
#              'title': 'What will the high be in Chicago on Oct 10, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT09',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 9, 2022',
#              'title': 'What will the high be in Chicago on Oct 9, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT08',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 8, 2022',
#              'title': 'What will the high be in Chicago on Oct 8, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT07',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 7, 2022',
#              'title': 'What will the high be in Chicago on Oct 7, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT06',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 6, 2022',
#              'title': 'What will the high be in Chicago on Oct 6, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT05',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 5, 2022',
#              'title': 'What will the high be in Chicago on Oct 5, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT04',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 4, 2022',
#              'title': 'What will the high be in Chicago on Oct 4, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22OCT03',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Oct 3, 2022',
#              'title': 'What will the high be in Chicago on Oct 3, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22SEP30',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Sep 30, 2022',
#              'title': 'What will the high be in Chicago on Sep 30, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22SEP29',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Sep 29, 2022',
#              'title': 'What will the high be in Chicago on Sep 29, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22SEP28',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Sep 28, 2022',
#              'title': 'What will the high be in Chicago on Sep 28, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22SEP23',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Sep 23, 2022',
#              'title': 'What will the high be in Chicago on Sep 23, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22SEP22',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On Sep 22, 2022',
#              'title': 'What will the high be in Chicago on Sep 22, 2022?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22SEP21',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On September 21, 2022',
#              'title': 'What will the high be in Chicago on Wed?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22JUN04',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On June 04, 2022',
#              'title': 'What will the high be in Chicago on Sat?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22JUN03',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On June 03, 2022',
#              'title': 'What will the high be in Chicago on Fri?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22MAY26',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On May 26, 2022',
#              'title': 'What will the high be in Chicago on Thu?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'HIGHCHI-22MAY25',
#              'mutually_exclusive': True,
#              'series_ticker': 'HIGHCHI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'On May 25, 2022',
#              'title': 'What will the high be in Chicago on Wed?'}]}

# %%
import json
# Gets the data for a specific event.
eventTicker = 'HIGHCHI-24MAR19'
eventResponse = kalshi_api.get_event(eventTicker)

# Parse JSON
data = eventResponse.to_dict()

# Extract tickers for each market
tickers = [market['ticker'] for market in data['markets']]

# Print tickers
for ticker in tickers:
    print(ticker)
# Out:
# HIGHCHI-24MAR19-T51
# HIGHCHI-24MAR19-B51.5
# HIGHCHI-24MAR19-B53.5
# HIGHCHI-24MAR19-B55.5
# HIGHCHI-24MAR19-B57.5
# HIGHCHI-24MAR19-T58

# %%
import json

def get_market_tickers_for_event(event_ticker):
    # Assuming kalshi_api.get_event() retrieves data for the given event ticker
    eventResponse = kalshi_api.get_event(event_ticker)
    
    # Parse JSON
    data = eventResponse.to_dict()

    # Extract tickers for each market
    tickers = [market['ticker'] for market in data['markets']]
    
    return tickers

# Example usage
event_ticker = 'HIGHMIA-24MAR20'
tickers = get_market_tickers_for_event(event_ticker)
for ticker in tickers:
    print(ticker)
# Out:
# HIGHMIA-24MAR20-T74
# HIGHMIA-24MAR20-B74.5
# HIGHMIA-24MAR20-B76.5
# HIGHMIA-24MAR20-B78.5
# HIGHMIA-24MAR20-B80.5
# HIGHMIA-24MAR20-T81

# %%
if exchangeStatus.trading_active:
    # Submit an order for 10 yes contracts at 50cents on 'FED-23DEC-T3.00'.
    orderUuid = str(uuid.uuid4())
    orderResponse = kalshi_api.create_order(CreateOrderRequest(
        ticker='HIGHCHI-24MAR20-T42',
        action='buy',
        type='limit',
        yes_price=1,
        count=1,
        client_order_id=orderUuid,
        side='yes',
    ))
    print('\nOrder submitted: ')
    pprint(orderResponse)
else:
    print('\nThe exchange is not trading active, no orders will be sent right now.')
# Out:
# Order submitted:
# {'order': {'action': 'buy',
#            'client_order_id': '2fb0438d-d06d-4b5d-b44a-182bab509349',
#            'created_time': '2024-03-20T18:09:39.844144Z',
#            'expiration_time': None,
#            'no_price': 99,
#            'order_id': 'bfd14062-229a-4585-a5b0-01902fcdddb8',
#            'side': 'yes',
#            'status': 'resting',
#            'ticker': 'HIGHCHI-24MAR20-T42',
#            'type': 'limit',
#            'user_id': '85e87b65-dfb8-4ba7-a122-d7e187de00aa',
#            'yes_price': 1}}

# %%
'''nyc - 48
aus - 58
mia - 66'''
if exchangeStatus.trading_active:
    # Submit an order for 10 yes contracts at 50cents on 'FED-23DEC-T3.00'.
    orderUuid = str(uuid.uuid4())
    orderResponse = kalshi_api.create_order(CreateOrderRequest(
        ticker='HIGHNY-24MAR20-T51',
        action='buy',
        type='limit',
        yes_price=1,
        count=1,
        client_order_id=orderUuid,
        side='yes',
    ))
    print('\nOrder submitted: ')
    pprint(orderResponse)
else:
    print('\nThe exchange is not trading active, no orders will be sent right now.')

if exchangeStatus.trading_active:
    # Submit an order for 10 yes contracts at 50cents on 'FED-23DEC-T3.00'.
    orderUuid = str(uuid.uuid4())
    orderResponse = kalshi_api.create_order(CreateOrderRequest(
        ticker='HIGHAUS-24MAR20-T63',
        action='buy',
        type='limit',
        yes_price=1,
        count=1,
        client_order_id=orderUuid,
        side='yes',
    ))
    print('\nOrder submitted: ')
    pprint(orderResponse)
else:
    print('\nThe exchange is not trading active, no orders will be sent right now.')

if exchangeStatus.trading_active:
    # Submit an order for 10 yes contracts at 50cents on 'FED-23DEC-T3.00'.
    orderUuid = str(uuid.uuid4())
    orderResponse = kalshi_api.create_order(CreateOrderRequest(
        ticker='HIGHMIA-24MAR20-T74',
        action='buy',
        type='limit',
        yes_price=1,
        count=1,
        client_order_id=orderUuid,
        side='yes',
    ))
    print('\nOrder submitted: ')
    pprint(orderResponse)
else:
    print('\nThe exchange is not trading active, no orders will be sent right now.')
# Out:
# Order submitted:
# {'order': {'action': 'buy',
#            'client_order_id': '4d779f40-2562-4070-a12e-b445f837178f',
#            'created_time': '2024-03-20T20:29:18.663836Z',
#            'expiration_time': None,
#            'no_price': 99,
#            'order_id': '1be25a63-5fc0-4fa1-be1b-8eb3a63841bb',
#            'side': 'yes',
#            'status': 'resting',
#            'ticker': 'HIGHNY-24MAR20-T51',
#            'type': 'limit',
#            'user_id': '85e87b65-dfb8-4ba7-a122-d7e187de00aa',
#            'yes_price': 1}}
#
# Order submitted:
# {'order': {'action': 'buy',
#            'client_order_id': '3bf622fc-8f9c-4239-9870-30d1db377cd4',
#            'created_time': '2024-03-20T20:29:18.760629Z',
#            'expiration_time': None,
#            'no_price': 99,
#            'order_id': '80d3ea17-51ad-407e-8ec5-0095dc5926e3',
#            'side': 'yes',
#            'status': 'resting',
#            'ticker': 'HIGHAUS-24MAR20-T63',
#            'type': 'limit',
#            'user_id': '85e87b65-dfb8-4ba7-a122-d7e187de00aa',
#            'yes_price': 1}}
#
# Order submitted:
# {'order': {'action': 'buy',
#            'client_order_id': 'de7cae88-1bdb-4130-83dc-4b4b3d8f365f',
#            'created_time': '2024-03-20T20:29:19.022122Z',
#            'expiration_time': None,
#            'no_price': 99,
#            'order_id': 'c8d132d1-dcd8-47a4-86a7-cb3908b4e7b8',
#            'side': 'yes',
#            'status': 'executed',
#            'ticker': 'HIGHMIA-24MAR20-T74',
#            'type': 'limit',
#            'user_id': '85e87b65-dfb8-4ba7-a122-d7e187de00aa',
#            'yes_price': 1}}
